# %% [markdown]
# ## Impact of tides on various things

# %% [markdown]
# ### Define utils

# %%
import numpy as np
import netCDF4 as nc
import glob
import os
from scipy.interpolate import PchipInterpolator

import matplotlib as mpl
font = {'family' : 'sans',
        'size'   : 12}

mpl.rc('font', **font)
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.ticker import MultipleLocator, LogLocator, MaxNLocator
import matplotlib.pyplot as plt

import pandas as pd
from cmcrameri import cm

# %%
R_earth = 6.371e6 # m

# %%
from proteus.config import read_config
import utils.load_grid as lg

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %matplotlib widget

# %%
def readrun(f, stride=1):
    print("Reading files in '%s'..." % f)
    ncdfs = glob.glob(f+"/data/*_atm.nc")
    if len(ncdfs) == 0:
        raise Exception("No files found!")

    years = [float(s.split("/")[-1].split("_")[0]) for s in ncdfs]

    if stride < 0:
        mask = [np.argsort(years)[-1]]
    else:
        mask = np.argsort(years)[::int(stride)]

    ncdfs = np.array([ncdfs[i] for i in mask])
    years = np.array([years[i] for i in mask])
    data  = np.array([lg.readncdf(f) for f in ncdfs])

    print("    Done reading %d files" % len(years))
    print("    Final time = %1.3e years" % years[-1])
    return years, data

def read_helpfile(fpath):
    return pd.read_csv(fpath, sep=r'\s+')

# %% [markdown]
# ### Do analysis

# %%
outname = "output/l9859c_grid6/"
title = "L 98-59 5"

stride = -1

indep_var = "orbit.dummy.H_tide"
indep_lbl = r"Tidal heating [W kg$^{-1}$]"

cmap = cm.batlow

# %%
pgrid_dir = "data/" + outname
globber = pgrid_dir + "/case_*/"
print(globber)
cases = glob.glob(globber)

npoints = len(cases)
print("npoints = %d"%npoints)
if npoints < 1:
    raise

data = []
help = []
conf = []
post = []
cnum = []
for folder in cases:
    _,d = readrun(folder, stride=stride)
    data.append( d )
    conf.append( read_config(folder+"init_coupler.toml") )
    help.append( read_helpfile(folder+"runtime_helpfile.csv") )
    cnum.append(int(folder.split("_")[-1].replace("/","")))

statuses = lg.get_statuses(pgrid_dir)

print("Done")
# Out:
# data/output/l9859c_grid6//case_*/
# npoints = 225
# Reading files in 'data/output/l9859c_grid6/case_00000/'...
#     Done reading 1 files
#     Final time = 2.871e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00001/'...
#     Done reading 1 files
#     Final time = 5.549e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00002/'...
#     Done reading 1 files
#     Final time = 1.351e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00003/'...
#     Done reading 1 files
#     Final time = 2.811e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00004/'...
#     Done reading 1 files
#     Final time = 4.274e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00005/'...
#     Done reading 1 files
#     Final time = 2.880e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00006/'...
#     Done reading 1 files
#     Final time = 5.570e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00007/'...
#     Done reading 1 files
#     Final time = 1.357e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00008/'...
#     Done reading 1 files
#     Final time = 2.936e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00009/'...
#     Done reading 1 files
#     Final time = 5.572e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00010/'...
#     Done reading 1 files
#     Final time = 3.394e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00011/'...
#     Done reading 1 files
#     Final time = 9.037e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00012/'...
#     Done reading 1 files
#     Final time = 1.753e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00013/'...
#     Done reading 1 files
#     Final time = 2.699e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00014/'...
#     Done reading 1 files
#     Final time = 3.260e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00015/'...
#     Done reading 1 files
#     Final time = 4.018e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00016/'...
#     Done reading 1 files
#     Final time = 6.554e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00017/'...
#     Done reading 1 files
#     Final time = 1.106e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00018/'...
#     Done reading 1 files
#     Final time = 1.541e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00019/'...
#     Done reading 1 files
#     Final time = 1.976e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00020/'...
#     Done reading 1 files
#     Final time = 2.545e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00021/'...
#     Done reading 1 files
#     Final time = 3.550e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00022/'...
#     Done reading 1 files
#     Final time = 6.021e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00023/'...
#     Done reading 1 files
#     Final time = 9.120e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00024/'...
#     Done reading 1 files
#     Final time = 1.207e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00025/'...
#     Done reading 1 files
#     Final time = 1.457e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00026/'...
#     Done reading 1 files
#     Final time = 2.868e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00027/'...
#     Done reading 1 files
#     Final time = 2.372e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00028/'...
#     Done reading 1 files
#     Final time = 4.760e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00029/'...
#     Done reading 1 files
#     Final time = 4.860e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00030/'...
#     Done reading 1 files
#     Final time = 7.957e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00031/'...
#     Done reading 1 files
#     Final time = 6.690e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00032/'...
#     Done reading 1 files
#     Final time = 1.952e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00033/'...
#     Done reading 1 files
#     Final time = 9.861e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00034/'...
#     Done reading 1 files
#     Final time = 1.010e+09 years
# Reading files in 'data/output/l9859c_grid6/case_00035/'...
#     Done reading 1 files
#     Final time = 3.628e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00036/'...
#     Done reading 1 files
#     Final time = 4.700e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00037/'...
#     Done reading 1 files
#     Final time = 2.034e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00038/'...
#     Done reading 1 files
#     Final time = 1.896e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00039/'...
#     Done reading 1 files
#     Final time = 6.930e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00040/'...
#     Done reading 1 files
#     Final time = 5.025e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00041/'...
#     Done reading 1 files
#     Final time = 5.747e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00042/'...
#     Done reading 1 files
#     Final time = 4.263e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00043/'...
#     Done reading 1 files
#     Final time = 1.230e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00044/'...
#     Done reading 1 files
#     Final time = 1.501e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00045/'...
#     Done reading 1 files
#     Final time = 8.685e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00046/'...
#     Done reading 1 files
#     Final time = 2.259e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00047/'...
#     Done reading 1 files
#     Final time = 7.666e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00048/'...
#     Done reading 1 files
#     Final time = 1.988e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00049/'...
#     Done reading 1 files
#     Final time = 3.364e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00050/'...
#     Done reading 1 files
#     Final time = 8.165e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00051/'...
#     Done reading 1 files
#     Final time = 3.612e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00052/'...
#     Done reading 1 files
#     Final time = 6.581e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00053/'...
#     Done reading 1 files
#     Final time = 1.290e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00054/'...
#     Done reading 1 files
#     Final time = 2.003e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00055/'...
#     Done reading 1 files
#     Final time = 6.189e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00056/'...
#     Done reading 1 files
#     Final time = 1.131e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00057/'...
#     Done reading 1 files
#     Final time = 2.730e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00058/'...
#     Done reading 1 files
#     Final time = 4.670e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00059/'...
#     Done reading 1 files
#     Final time = 6.417e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00060/'...
#     Done reading 1 files
#     Final time = 3.255e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00061/'...
#     Done reading 1 files
#     Final time = 6.128e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00062/'...
#     Done reading 1 files
#     Final time = 1.390e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00063/'...
#     Done reading 1 files
#     Final time = 2.923e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00064/'...
#     Done reading 1 files
#     Final time = 4.770e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00065/'...
#     Done reading 1 files
#     Final time = 1.760e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00066/'...
#     Done reading 1 files
#     Final time = 3.129e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00067/'...
#     Done reading 1 files
#     Final time = 1.013e+09 years
# Reading files in 'data/output/l9859c_grid6/case_00068/'...
#     Done reading 1 files
#     Final time = 8.390e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00069/'...
#     Done reading 1 files
#     Final time = 1.498e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00070/'...
#     Done reading 1 files
#     Final time = 9.986e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00071/'...
#     Done reading 1 files
#     Final time = 8.173e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00072/'...
#     Done reading 1 files
#     Final time = 2.060e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00073/'...
#     Done reading 1 files
#     Final time = 1.746e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00074/'...
#     Done reading 1 files
#     Final time = 7.981e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00075/'...
#     Done reading 1 files
#     Final time = 5.854e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00076/'...
#     Done reading 1 files
#     Final time = 4.516e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00077/'...
#     Done reading 1 files
#     Final time = 3.192e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00078/'...
#     Done reading 1 files
#     Final time = 6.909e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00079/'...
#     Done reading 1 files
#     Final time = 4.116e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00080/'...
#     Done reading 1 files
#     Final time = 3.935e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00081/'...
#     Done reading 1 files
#     Final time = 4.040e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00082/'...
#     Done reading 1 files
#     Final time = 3.040e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00083/'...
#     Done reading 1 files
#     Final time = 1.112e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00084/'...
#     Done reading 1 files
#     Final time = 1.953e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00085/'...
#     Done reading 1 files
#     Final time = 2.685e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00086/'...
#     Done reading 1 files
#     Final time = 4.015e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00087/'...
#     Done reading 1 files
#     Final time = 4.750e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00088/'...
#     Done reading 1 files
#     Final time = 1.754e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00089/'...
#     Done reading 1 files
#     Final time = 3.158e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00090/'...
#     Done reading 1 files
#     Final time = 1.602e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00091/'...
#     Done reading 1 files
#     Final time = 7.574e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00092/'...
#     Done reading 1 files
#     Final time = 2.968e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00093/'...
#     Done reading 1 files
#     Final time = 6.451e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00094/'...
#     Done reading 1 files
#     Final time = 1.013e+09 years
# Reading files in 'data/output/l9859c_grid6/case_00095/'...
#     Done reading 1 files
#     Final time = 6.290e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00096/'...
#     Done reading 1 files
#     Final time = 1.363e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00097/'...
#     Done reading 1 files
#     Final time = 4.220e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00098/'...
#     Done reading 1 files
#     Final time = 1.159e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00099/'...
#     Done reading 1 files
#     Final time = 1.857e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00100/'...
#     Done reading 1 files
#     Final time = 4.488e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00101/'...
#     Done reading 1 files
#     Final time = 8.696e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00102/'...
#     Done reading 1 files
#     Final time = 1.964e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00103/'...
#     Done reading 1 files
#     Final time = 3.625e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00104/'...
#     Done reading 1 files
#     Final time = 5.857e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00105/'...
#     Done reading 1 files
#     Final time = 2.945e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00106/'...
#     Done reading 1 files
#     Final time = 5.315e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00107/'...
#     Done reading 1 files
#     Final time = 1.141e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00108/'...
#     Done reading 1 files
#     Final time = 2.230e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00109/'...
#     Done reading 1 files
#     Final time = 3.970e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00110/'...
#     Done reading 1 files
#     Final time = 1.708e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00111/'...
#     Done reading 1 files
#     Final time = 2.913e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00112/'...
#     Done reading 1 files
#     Final time = 9.683e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00113/'...
#     Done reading 1 files
#     Final time = 5.523e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00114/'...
#     Done reading 1 files
#     Final time = 9.899e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00115/'...
#     Done reading 1 files
#     Final time = 9.867e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00116/'...
#     Done reading 1 files
#     Final time = 1.692e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00117/'...
#     Done reading 1 files
#     Final time = 1.026e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00118/'...
#     Done reading 1 files
#     Final time = 3.012e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00119/'...
#     Done reading 1 files
#     Final time = 7.839e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00120/'...
#     Done reading 1 files
#     Final time = 5.516e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00121/'...
#     Done reading 1 files
#     Final time = 1.138e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00122/'...
#     Done reading 1 files
#     Final time = 7.160e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00123/'...
#     Done reading 1 files
#     Final time = 1.959e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00124/'...
#     Done reading 1 files
#     Final time = 3.420e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00125/'...
#     Done reading 1 files
#     Final time = 3.753e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00126/'...
#     Done reading 1 files
#     Final time = 3.257e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00127/'...
#     Done reading 1 files
#     Final time = 2.129e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00128/'...
#     Done reading 1 files
#     Final time = 9.677e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00129/'...
#     Done reading 1 files
#     Final time = 6.885e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00130/'...
#     Done reading 1 files
#     Final time = 2.245e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00131/'...
#     Done reading 1 files
#     Final time = 6.644e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00132/'...
#     Done reading 1 files
#     Final time = 5.318e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00133/'...
#     Done reading 1 files
#     Final time = 3.217e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00134/'...
#     Done reading 1 files
#     Final time = 2.430e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00135/'...
#     Done reading 1 files
#     Final time = 3.070e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00136/'...
#     Done reading 1 files
#     Final time = 1.144e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00137/'...
#     Done reading 1 files
#     Final time = 4.868e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00138/'...
#     Done reading 1 files
#     Final time = 1.002e+09 years
# Reading files in 'data/output/l9859c_grid6/case_00139/'...
#     Done reading 1 files
#     Final time = 1.011e+09 years
# Reading files in 'data/output/l9859c_grid6/case_00140/'...
#     Done reading 1 files
#     Final time = 5.301e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00141/'...
#     Done reading 1 files
#     Final time = 1.230e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00142/'...
#     Done reading 1 files
#     Final time = 3.765e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00143/'...
#     Done reading 1 files
#     Final time = 9.590e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00144/'...
#     Done reading 1 files
#     Final time = 1.613e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00145/'...
#     Done reading 1 files
#     Final time = 4.057e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00146/'...
#     Done reading 1 files
#     Final time = 9.426e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00147/'...
#     Done reading 1 files
#     Final time = 2.006e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00148/'...
#     Done reading 1 files
#     Final time = 3.648e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00149/'...
#     Done reading 1 files
#     Final time = 5.352e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00150/'...
#     Done reading 1 files
#     Final time = 2.622e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00151/'...
#     Done reading 1 files
#     Final time = 4.923e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00152/'...
#     Done reading 1 files
#     Final time = 1.177e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00153/'...
#     Done reading 1 files
#     Final time = 2.129e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00154/'...
#     Done reading 1 files
#     Final time = 3.627e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00155/'...
#     Done reading 1 files
#     Final time = 1.397e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00156/'...
#     Done reading 1 files
#     Final time = 2.765e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00157/'...
#     Done reading 1 files
#     Final time = 1.842e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00158/'...
#     Done reading 1 files
#     Final time = 6.038e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00159/'...
#     Done reading 1 files
#     Final time = 9.381e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00160/'...
#     Done reading 1 files
#     Final time = 8.475e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00161/'...
#     Done reading 1 files
#     Final time = 1.609e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00162/'...
#     Done reading 1 files
#     Final time = 4.743e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00163/'...
#     Done reading 1 files
#     Final time = 1.017e+09 years
# Reading files in 'data/output/l9859c_grid6/case_00164/'...
#     Done reading 1 files
#     Final time = 9.334e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00165/'...
#     Done reading 1 files
#     Final time = 5.112e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00166/'...
#     Done reading 1 files
#     Final time = 5.506e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00167/'...
#     Done reading 1 files
#     Final time = 1.215e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00168/'...
#     Done reading 1 files
#     Final time = 1.930e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00169/'...
#     Done reading 1 files
#     Final time = 5.366e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00170/'...
#     Done reading 1 files
#     Final time = 1.238e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00171/'...
#     Done reading 1 files
#     Final time = 5.597e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00172/'...
#     Done reading 1 files
#     Final time = 1.025e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00173/'...
#     Done reading 1 files
#     Final time = 5.533e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00174/'...
#     Done reading 1 files
#     Final time = 1.541e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00175/'...
#     Done reading 1 files
#     Final time = 1.193e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00176/'...
#     Done reading 1 files
#     Final time = 1.867e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00177/'...
#     Done reading 1 files
#     Final time = 2.666e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00178/'...
#     Done reading 1 files
#     Final time = 9.034e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00179/'...
#     Done reading 1 files
#     Final time = 2.402e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00180/'...
#     Done reading 1 files
#     Final time = 3.641e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00181/'...
#     Done reading 1 files
#     Final time = 1.845e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00182/'...
#     Done reading 1 files
#     Final time = 5.468e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00183/'...
#     Done reading 1 files
#     Final time = 1.014e+09 years
# Reading files in 'data/output/l9859c_grid6/case_00184/'...
#     Done reading 1 files
#     Final time = 1.013e+09 years
# Reading files in 'data/output/l9859c_grid6/case_00185/'...
#     Done reading 1 files
#     Final time = 5.430e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00186/'...
#     Done reading 1 files
#     Final time = 1.187e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00187/'...
#     Done reading 1 files
#     Final time = 3.436e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00188/'...
#     Done reading 1 files
#     Final time = 8.773e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00189/'...
#     Done reading 1 files
#     Final time = 1.494e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00190/'...
#     Done reading 1 files
#     Final time = 4.647e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00191/'...
#     Done reading 1 files
#     Final time = 8.922e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00192/'...
#     Done reading 1 files
#     Final time = 1.926e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00193/'...
#     Done reading 1 files
#     Final time = 3.517e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00194/'...
#     Done reading 1 files
#     Final time = 4.803e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00195/'...
#     Done reading 1 files
#     Final time = 2.987e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00196/'...
#     Done reading 1 files
#     Final time = 5.676e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00197/'...
#     Done reading 1 files
#     Final time = 1.123e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00198/'...
#     Done reading 1 files
#     Final time = 2.026e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00199/'...
#     Done reading 1 files
#     Final time = 1.026e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00200/'...
#     Done reading 1 files
#     Final time = 1.790e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00201/'...
#     Done reading 1 files
#     Final time = 3.221e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00202/'...
#     Done reading 1 files
#     Final time = 6.399e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00203/'...
#     Done reading 1 files
#     Final time = 1.459e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00204/'...
#     Done reading 1 files
#     Final time = 9.659e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00205/'...
#     Done reading 1 files
#     Final time = 1.058e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00206/'...
#     Done reading 1 files
#     Final time = 1.730e+06 years
# Reading files in 'data/output/l9859c_grid6/case_00207/'...
#     Done reading 1 files
#     Final time = 1.072e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00208/'...
#     Done reading 1 files
#     Final time = 1.013e+09 years
# Reading files in 'data/output/l9859c_grid6/case_00209/'...
#     Done reading 1 files
#     Final time = 6.426e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00210/'...
#     Done reading 1 files
#     Final time = 5.837e+05 years
# Reading files in 'data/output/l9859c_grid6/case_00211/'...
#     Done reading 1 files
#     Final time = 7.157e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00212/'...
#     Done reading 1 files
#     Final time = 1.867e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00213/'...
#     Done reading 1 files
#     Final time = 7.313e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00214/'...
#     Done reading 1 files
#     Final time = 4.240e+08 years
# Reading files in 'data/output/l9859c_grid6/case_00215/'...
#     Done reading 1 files
#     Final time = 3.360e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00216/'...
#     Done reading 1 files
#     Final time = 3.850e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00217/'...
#     Done reading 1 files
#     Final time = 6.696e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00218/'...
#     Done reading 1 files
#     Final time = 5.823e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00219/'...
#     Done reading 1 files
#     Final time = 8.344e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00220/'...
#     Done reading 1 files
#     Final time = 5.645e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00221/'...
#     Done reading 1 files
#     Final time = 2.631e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00222/'...
#     Done reading 1 files
#     Final time = 2.616e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00223/'...
#     Done reading 1 files
#     Final time = 5.838e+07 years
# Reading files in 'data/output/l9859c_grid6/case_00224/'...
#     Done reading 1 files
#     Final time = 2.054e+07 years
# Done

# %%
indep_vals = []
for i in range(npoints):
    indep_vals.append(lg.descend_get(conf[i],indep_var))
indep_vals = np.array(indep_vals)
indep_max = np.amax(np.abs(indep_vals))
indep_min = np.amin(np.abs(indep_vals))

isorted = np.argsort(indep_vals)

linthresh = np.amin(indep_vals[indep_vals>0])

# %%
norm = mpl.colors.SymLogNorm(vmin=indep_min, vmax=indep_max, linthresh=linthresh)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)

# %%
plt.close("all")
fig,axs = plt.subplots(1,2, sharey=True, width_ratios=(0.7, 0.3), figsize=(5,4))
(ax0,ax1) = axs

al = 0.6

for i in range(npoints):
    ds = data[i][-1]
    st = statuses[cnum[i]]

    x = ds["tmpl"] / 1e3
    y = ds["pl"] * 1e-5

    if not (10 <= st <= 19 ):
        print("Skip case %d"%cnum[i])
        continue

    indep_val = lg.descend_get(conf[i],indep_var)
    col = sm.to_rgba(indep_val)
    zorder=isorted[::-1][i]

    ax0.plot(x,y, color=col, zorder=2*zorder, alpha=al)

    # m = np.argwhere(ds["fl_cnvct"] > 0)
    # x_mask = x[m]
    # y_mask = y[m]
    # ax0.scatter(x_mask,y_mask, color=col, s=20, edgecolors='w', marker='o', zorder=2*zorder+1)

    x = ds["fl_cnvct"]/1e3
    ax1.plot(x,y, color=col, zorder=2*zorder, alpha=al)

ax0.set_yscale("log")
ax0.invert_yaxis()
ax0.set_ylabel("Pressure [bar]")
ax0.set_xlabel("Temperature \n" + r"[$10^3$ K]")
ax0.xaxis.set_major_locator(MultipleLocator(0.5))
ax0.xaxis.set_minor_locator(MultipleLocator(0.1))

ax1.set_xlabel("Convection \n" + r"[kW m$^{-2}$]")
ax1.xaxis.set_major_locator(MultipleLocator(1.0))
ax1.xaxis.set_minor_locator(MultipleLocator(0.5))

fig.subplots_adjust(right=0.88)
cbar_ax = fig.add_axes([0.9, 0.15, 0.03, 0.7])
cbar = fig.colorbar(sm, cax=cbar_ax)
cbar.set_label(indep_lbl)

fig.subplots_adjust(wspace=0.03)
plt.show()
# Out:
# Skip case 136

# %%
fig,axs = plt.subplots(4,1, sharex=True, figsize=(6,6))

ms=40
lvl = 0

pltdat = [{"x":[], "y":[], "c":[], "ylbl":"", "yscl":"linear", "ysl":1} for _ in range(len(axs))]

for i in range(npoints):
    ds = data[i][-1]
    hf = help[i].iloc[-1]
    indep_val = lg.descend_get(conf[i],indep_var)
    col = sm.to_rgba(indep_val)

    pltdat[0]["ylbl"] = "Max cnvct \n [W m-2]"
    pltdat[0]["yscl"] = "symlog"
    pltdat[0]["ythr"]  = 1
    pltdat[0]["x"].append(indep_val)
    pltdat[0]["y"].append(np.amax(ds["fl_cnvct"]))
    pltdat[0]["c"].append(col)

    axs[1].yaxis.set_major_locator(MultipleLocator(1))
    axs[1].yaxis.set_minor_locator(MultipleLocator(0.25))
    pltdat[1]["ylbl"] = "Transit radius \n [R_e]"
    pltdat[1]["x"].append(indep_val)
    pltdat[1]["y"].append((hf["R_int"] + hf["z_obs"]) / R_earth)
    pltdat[1]["c"].append(col)

    pltdat[2]["ylbl"] = "Net flux \n [W m-2]"
    pltdat[2]["yscl"] = "log"
    pltdat[2]["x"].append(indep_val)
    pltdat[2]["y"].append(ds["fl_tot"][lvl])
    pltdat[2]["c"].append(col)

    axs[3].yaxis.set_major_locator(MultipleLocator(20))
    axs[3].yaxis.set_minor_locator(MultipleLocator(10))
    pltdat[3]["ylbl"] = "Melt frac \n [%]"
    pltdat[3]["x"].append(indep_val)
    pltdat[3]["y"].append(hf["Phi_global"] * 100)
    pltdat[3]["c"].append(col)

for i,q in enumerate(pltdat):
    axs[i].grid(zorder=-1, alpha=0.5)
    axs[i].scatter(q["x"], q["y"], color=q["c"], s=ms, zorder=i+3)
    axs[i].set_ylabel(pltdat[i]["ylbl"])
    if pltdat[i]["yscl"] == "symlog":
        axs[i].set_yscale("symlog", linthresh=pltdat[i]["ythr"])
    else:
        axs[i].set_yscale(pltdat[i]["yscl"])

axs[-1].set_xlabel(indep_lbl)
axs[-1].set_xscale("symlog", linthresh=linthresh)

plt.show()

# %%
def plot_sensitivity(var='T_surf', box_plot=False):

    fig, ax = plt.subplots(1,1, figsize=(4,3))

    x = {}
    for k in indep_vals:
        x[k] = []

    for i in range(npoints):
        ds = data[i][-1]
        hf = help[i].iloc[-1]
        k = lg.descend_get(conf[i],indep_var)
        st = statuses[cnum[i]]

        if not (10 <= st <= 19 ):
            print("Skip case %d"%cnum[i])
            continue

        if var == 'fl_cnvct':
            y = np.amax(ds["fl_cnvct"])
        elif var == 'T_surf':
            y = hf["T_surf"]
        elif var == "Phi_global":
            y = hf["Phi_global"] * 100.0
        elif var == "rho_obs":
            y = hf["rho_obs"] * 0.001
        elif var == "contrast_ratio":
            y = hf["contrast_ratio"] * 1e9
        else:
            raise Exception(f"Invalid variable name {var}")
        x[k].append(y)

    for k in set(indep_vals):
        if k > 0.0:
            x_pos = k
            x_wid = x_pos/2
        else:
            x_pos = 0.0
            x_wid = linthresh/2

        if box_plot:
            bplot = ax.boxplot(x[k], positions=[x_pos], widths=[x_wid], zorder=10,
                            patch_artist=True, showfliers=True) #, showmeans=True, meanline=True)
            bplot['boxes'][0].set_facecolor('lightgrey') # make opaque

        else:
            ys = x[k]
            xs = [x_pos for _ in ys]
            ax.scatter(xs, ys, zorder=10, color='k', alpha=0.8, s=12 )

    ax.set_xlabel(r"Tidal heating [W kg$^{-1}$]")

    if var == 'fl_cnvct':
        ax.set_ylabel(r"Convection [W m$^{-2}$]")
        ax.yaxis.set_major_locator(MultipleLocator(500))
        ax.yaxis.set_minor_locator(MultipleLocator(100))
        ax.set_ylim(bottom=0, top=3000)

    elif var == 'T_surf':
        ax.set_ylabel(r"Surface temperature [K]")
        ax.yaxis.set_major_locator(MultipleLocator(250))
        ax.yaxis.set_minor_locator(MultipleLocator(50))
        ax.set_ylim(bottom=1500, top=3000)

    elif var == 'Phi_global':
        ax.set_ylabel(r"Mantle melt fraction [%]")
        ax.yaxis.set_major_locator(MultipleLocator(20))
        ax.yaxis.set_minor_locator(MultipleLocator(10))
        ax.set_ylim(bottom=0, top=100)

    elif var == 'rho_obs':
        ax.set_ylabel(r"Bulk density [g cm$^{-3}$]")
        ax.yaxis.set_major_locator(MultipleLocator(1))
        ax.yaxis.set_minor_locator(MultipleLocator(0.2))

    elif var == 'contrast_ratio':
        ax.set_ylabel(r"Contrast ratio [ppb]")
        # ax.yaxis.set_major_locator(MultipleLocator(1))
        # ax.yaxis.set_minor_locator(MultipleLocator(0.2))

    xticks = np.unique(sorted(indep_vals))
    ax.set_xlim(left=-linthresh/2, right=np.amax(indep_vals)*2)
    ax.set_xscale("symlog", linthresh=linthresh)
    ax.set_xticks(xticks)
    ax.grid(axis='y', zorder=0)

    plt.show()

# %%
for var in ("Phi_global", "T_surf", "fl_cnvct", "rho_obs", "contrast_ratio"):
    plot_sensitivity(var=var, box_plot=True)
# Out:
# Skip case 136
# Skip case 136
# Skip case 136
# Skip case 136
# Skip case 136
